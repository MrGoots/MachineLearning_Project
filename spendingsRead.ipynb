# %%
import numpy as np
import pandas as pd
import os
import warnings
warnings.filterwarnings('ignore')

# %%
os.listdir('spendings')
# Out:
# ['cu-msa-midwest-2-year-average-2005.xlsx',
#  'cu-msa-midwest-2-year-average-2006.xlsx',
#  'cu-msa-midwest-2-year-average-2007.xlsx',
#  'cu-msa-midwest-2-year-average-2008.xlsx',
#  'cu-msa-midwest-2-year-average-2009.xlsx',
#  'cu-msa-midwest-2-year-average-2010.xlsx',
#  'cu-msa-midwest-2-year-average-2011.xlsx',
#  'cu-msa-midwest-2-year-average-2012.xlsx',
#  'cu-msa-midwest-2-year-average-2013.xlsx',
#  'cu-msa-midwest-2-year-average-2014.xlsx',
#  'cu-msa-midwest-2-year-average-2015.xlsx',
#  'cu-msa-midwest-2-year-average-2016.xlsx',
#  'cu-msa-midwest-2-year-average-2017.xlsx',
#  'cu-msa-midwest-2-year-average-2018.xlsx',
#  'cu-msa-midwest-2-year-average-2019.xlsx',
#  'cu-msa-midwest-2-year-average-2020.xlsx',
#  'cu-msa-midwest-2-year-average-2021.xlsx',
#  'cu-msa-midwest-2-year-average-2022.xlsx',
#  'cu-msa-northeast-2-year-average-2005.xlsx',
#  'cu-msa-northeast-2-year-average-2006.xlsx',
#  'cu-msa-northeast-2-year-average-2007.xlsx',
#  'cu-msa-northeast-2-year-average-2008.xlsx',
#  'cu-msa-northeast-2-year-average-2009.xlsx',
#  'cu-msa-northeast-2-year-average-2010.xlsx',
#  'cu-msa-northeast-2-year-average-2011.xlsx',
#  'cu-msa-northeast-2-year-average-2012.xlsx',
#  'cu-msa-northeast-2-year-average-2013.xlsx',
#  'cu-msa-northeast-2-year-average-2014.xlsx',
#  'cu-msa-northeast-2-year-average-2015.xlsx',
#  'cu-msa-northeast-2-year-average-2016.xlsx',
#  'cu-msa-northeast-2-year-average-2017.xlsx',
#  'cu-msa-northeast-2-year-average-2018.xlsx',
#  'cu-msa-northeast-2-year-average-2019.xlsx',
#  'cu-msa-northeast-2-year-average-2020.xlsx',
#  'cu-msa-northeast-2-year-average-2021.xlsx',
#  'cu-msa-northeast-2-year-average-2022.xlsx',
#  'cu-msa-south-2-year-average-2005.xlsx',
#  'cu-msa-south-2-year-average-2006.xlsx',
#  'cu-msa-south-2-year-average-2007.xlsx',
#  'cu-msa-south-2-year-average-2008.xlsx',
#  'cu-msa-south-2-year-average-2009.xlsx',
#  'cu-msa-south-2-year-average-2010.xlsx',
#  'cu-msa-south-2-year-average-2011.xlsx',
#  'cu-msa-south-2-year-average-2012.xlsx',
#  'cu-msa-south-2-year-average-2013.xlsx',
#  'cu-msa-south-2-year-average-2014.xlsx',
#  'cu-msa-south-2-year-average-2015.xlsx',
#  'cu-msa-south-2-year-average-2016.xlsx',
#  'cu-msa-south-2-year-average-2017.xlsx',
#  'cu-msa-south-2-year-average-2018.xlsx',
#  'cu-msa-south-2-year-average-2019.xlsx',
#  'cu-msa-south-2-year-average-2020.xlsx',
#  'cu-msa-south-2-year-average-2021.xlsx',
#  'cu-msa-south-2-year-average-2022.xlsx',
#  'cu-msa-west-2-year-average-2005.xlsx',
#  'cu-msa-west-2-year-average-2006.xlsx',
#  'cu-msa-west-2-year-average-2007.xlsx',
#  'cu-msa-west-2-year-average-2008.xlsx',
#  'cu-msa-west-2-year-average-2009.xlsx',
#  'cu-msa-west-2-year-average-2010.xlsx',
#  'cu-msa-west-2-year-average-2011.xlsx',
#  'cu-msa-west-2-year-average-2012.xlsx',
#  'cu-msa-west-2-year-average-2013.xlsx',
#  'cu-msa-west-2-year-average-2014.xlsx',
#  'cu-msa-west-2-year-average-2015.xlsx',
#  'cu-msa-west-2-year-average-2016.xlsx',
#  'cu-msa-west-2-year-average-2017.xlsx',
#  'cu-msa-west-2-year-average-2018.xlsx',
#  'cu-msa-west-2-year-average-2019.xlsx',
#  'cu-msa-west-2-year-average-2020.xlsx',
#  'cu-msa-west-2-year-average-2021.xlsx',
#  'cu-msa-west-2-year-average-2022.xlsx']

# %%
startYear = 2005
endYear = 2022
regions = ['midwest','northeast','south','west']
years = np.arange(startYear,endYear+1)
catLst = ['Meats, poultry, fish, and eggs',
'Cereals and bakery products',
'Dairy products',
'Fruits and vegetables',
'Other food at home',
'Food away from home',
'Alcoholic beverages',
'Housing',
'Apparel and services',
'Transportation',
'Healthcare',
'Entertainment',
'Personal care products and services',
'Reading',
'Education',
'Tobacco products and smoking supplies',
'Miscellaneous',
'Cash contributions',
'Personal insurance and pensions']
### city names to replace
cityNames = {'Minneapolis-\nSt. Paul':'Minneapolis-St.Paul',
       'Washington,\nD.C.':'Washington, D.C.','Washington\nD.C.':'Washington, D.C.',
       'Dallas- Fort Worth':'Dallas-Fort Worth','Dallas-\nFort Worth':'Dallas-Fort Worth',
       'Los\nAngeles':'Los Angeles', 'San\nFrancisco':'San Francisco'}
### category names to replace
catNames = {'Health care':'Healthcare'}

# %%
final = pd.DataFrame()
for y in years:
    first = True
    for r in regions:
        temp = pd.read_excel(f'spendings/cu-msa-{r}-2-year-average-{y}.xlsx').dropna().reset_index(drop=True)
        temp.columns = temp.iloc[0]
        temp['Item'] = [i.strip() for i in temp['Item']]
        temp.set_index('Item',inplace=True)
        temp.rename(cityNames,axis='columns',errors='ignore',inplace=True)
        temp.rename(index=catNames,errors='ignore',inplace=True)  
        temp = temp.loc[catLst]     
        ### df is done
        if first:
            master = temp
            first = False
        else:
            master = pd.merge(master,temp,left_index=True,right_index=True,how ='outer')
    master['Year'] = np.full(master.shape[0],y)
    cols = [i for i in master.columns if 'All ' not in i]
    master = master[cols]
    ## save individual dfs
    master.to_csv(f'resources/spending_{y}.csv')
    final = pd.concat([final,master],axis = 0)
final
final.to_csv(f'resources/spending_{startYear}-{endYear}.csv')

# %%
master
# Out:
# 0                                     Chicago Detroit Minneapolis-St.Paul  \
# Item
# Meats, poultry, fish, and eggs           1269    1184                1100
# Cereals and bakery products               719     695                 680
# Dairy products                            492     510                 571
# Fruits and vegetables                    1115    1055                1241
# Other food at home                       2035    2051                2317
# Food away from home                      3741    2968                3507
# Alcoholic beverages                       907     655                1098
# Housing                                 27212   21746               27591
# Apparel and services                     2534    1744                1823
# Transportation                           9569   12566               10018
# Healthcare                               5946    5567                6688
# Entertainment                            3624    3855                4641
# Personal care products and services      1059     790                1075
# Reading                                   125      77                 247
# Education                                1686    1574                2496
# Tobacco products and smoking supplies     441     490                 284
# Miscellaneous                             998    1076                2063
# Cash contributions                       1474    1294                2810
# Personal insurance and pensions          9319    8968               12635
#
# 0                                     St. Louis New York Philadelphia Boston  \
# Item
# Meats, poultry, fish, and eggs             1170     1534         1269   1198
# Cereals and bakery products                 702      818          809    911
# Dairy products                              534      664          558    577
# Fruits and vegetables                      1045     1460         1237   1414
# Other food at home                         2252     2163         2252   2461
# Food away from home                        3817     4004         4366   4312
# Alcoholic beverages                         789      788          871   1100
# Housing                                   22255    31213        28453  31679
# Apparel and services                       1772     2699         3597   1807
# Transportation                            12262    10326        11247  11697
# Healthcare                                 6071     5154         6958   6923
