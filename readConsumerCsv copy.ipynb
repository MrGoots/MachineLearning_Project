# %%
import pandas as pd
import numpy as np

# %%
imports = pd.read_csv('resources/consumer_spending.csv')
#imports.set_index('Product',inplace=True)
# imports.index.names = ['Year']
#imports = imports.T
#imports.index.names = ['Year']
#imports

# %%
imports
# Out:
#                                                 GeoFIPS        GeoName Region  \
# 0                                               "00000"  United States
# 1                                               "00000"  United States
# 2                                               "00000"  United States
# 3                                               "00000"  United States
# 4                                               "00000"  United States
# ...                                                 ...            ...    ...
# 1439                                            "98000"       Far West      8
# 1440              Note: See the included footnote file.            NaN    NaN
# 1441  SAPCE1: Personal consumption expenditures (PCE...            NaN    NaN
# 1442  Last updated: October 4, 2023-- new statistics...            NaN    NaN
# 1443                   U.S. Bureau of Economic Analysis            NaN    NaN
#
#      TableName  LineCode IndustryClassification  \
# ...
